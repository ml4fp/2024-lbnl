# %% [markdown]
# # Pruning with Keras / TensorFlow

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
seed = 42
np.random.seed(seed)
import tensorflow as tf

tf.random.set_seed(seed)

# %% [markdown]
# ## Load the jet tagging dataset

# %%
X_train_val = np.load('X_train_val.npy')
X_test = np.load('X_test.npy')
y_train_val = np.load('y_train_val.npy')
y_test = np.load('y_test.npy')
classes = np.load('classes.npy', allow_pickle=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Load the pre-trained model
# The model is trained with jet-tagging open datase: `hls4ml_lhc_jets_hlf`.
#
# We used 3 hidden layers with 64, then 32, then 32 neurons. Each layer will use relu activation. Add an output layer with 5 neurons (one for each class), then finish with Softmax activation.
#
# Look at the **training notebook** to see the details:
# https://github.com/ml4fp/2024-lbnl/blob/main/efficient_ml/part1_karas_training.ipynb

# %%
model = load_model('baseline_model/KERAS_check_best_model.h5')
# Out:
# 2024-08-15 06:03:39.741687: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-15 06:03:40.374147: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 32521 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:c3:00.0, compute capability: 8.0

# %% [markdown]
# ## Train the pruned model

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning

pruned_model = Sequential()
pruned_model.add(Dense(64, input_shape=(16,), name="fc1", kernel_initializer="lecun_uniform", kernel_regularizer=l1(0.0001)))
pruned_model.add(Activation(activation="relu", name="relu1"))
pruned_model.add(Dense(32, name="fc2", kernel_initializer="lecun_uniform", kernel_regularizer=l1(0.0001)))
pruned_model.add(Activation(activation="relu", name="relu2"))
pruned_model.add(Dense(32, name="fc3", kernel_initializer="lecun_uniform", kernel_regularizer=l1(0.0001)))
pruned_model.add(Activation(activation="relu", name="relu3"))
pruned_model.add(Dense(5, name="output", kernel_initializer="lecun_uniform", kernel_regularizer=l1(0.0001)))
pruned_model.add(Activation(activation="softmax", name="softmax"))

pruning_params = {"pruning_schedule": pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
pruned_model = prune.prune_low_magnitude(pruned_model, **pruning_params)

# %%
adam = Adam(learning_rate=0.0001)
pruned_model.compile(optimizer=adam, loss=["categorical_crossentropy"], metrics=["accuracy"])
callbacks = all_callbacks(
    stop_patience=1000,
    lr_factor=0.5,
    lr_patience=10,
    lr_epsilon=0.000001,
    lr_cooldown=2,
    lr_minimum=0.0000001,
    outputDir="pruned_model",
)
callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
pruned_model.fit(
    X_train_val,
    y_train_val,
    batch_size=1024,
    epochs=30,
    validation_split=0.25,
    shuffle=True,
    callbacks=callbacks.callbacks,
    verbose=0,
)
# Save the model again but with the pruning 'stripped' to use the regular layer types
pruned_model = strip_pruning(pruned_model)
pruned_model.save("pruned_model/model_best.h5")
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0028s vs `on_train_batch_end` time: 0.0053s). Check your callbacks.
# 2024-08-15 06:03:56.232520: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 1: val_loss improved from inf to 1.12310, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 1: val_loss improved from inf to 1.12310, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 1: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 2: val_loss improved from 1.12310 to 0.97980, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 2: val_loss improved from 1.12310 to 0.97980, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 2: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 3: val_loss improved from 0.97980 to 0.90785, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 3: val_loss improved from 0.97980 to 0.90785, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 3: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 4: val_loss improved from 0.90785 to 0.87485, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 4: val_loss improved from 0.90785 to 0.87485, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 4: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 5: val_loss did not improve from 0.87485
#
# Epoch 5: val_loss did not improve from 0.87485
#
# Epoch 5: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 5: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 6: val_loss did not improve from 0.87485
#
# Epoch 6: val_loss did not improve from 0.87485
#
# Epoch 6: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 6: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 7: val_loss did not improve from 0.87485
#
# Epoch 7: val_loss did not improve from 0.87485
#
# Epoch 7: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 7: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 8: val_loss improved from 0.87485 to 0.86504, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 8: val_loss improved from 0.87485 to 0.86504, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 8: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 9: val_loss improved from 0.86504 to 0.84867, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 9: val_loss improved from 0.86504 to 0.84867, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 9: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 10: val_loss improved from 0.84867 to 0.83775, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 10: val_loss improved from 0.84867 to 0.83775, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 10: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to pruned_model/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 11: val_loss improved from 0.83775 to 0.82951, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 11: val_loss improved from 0.83775 to 0.82951, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 11: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 12: val_loss improved from 0.82951 to 0.82292, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 12: val_loss improved from 0.82951 to 0.82292, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 12: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 13: val_loss improved from 0.82292 to 0.81721, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 13: val_loss improved from 0.82292 to 0.81721, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 13: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 13: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 14: val_loss improved from 0.81721 to 0.81196, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 14: val_loss improved from 0.81721 to 0.81196, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 14: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 15: val_loss improved from 0.81196 to 0.80692, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 15: val_loss improved from 0.81196 to 0.80692, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 15: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 16: val_loss improved from 0.80692 to 0.80243, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 16: val_loss improved from 0.80692 to 0.80243, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 16: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 17: val_loss improved from 0.80243 to 0.79814, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 17: val_loss improved from 0.80243 to 0.79814, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 17: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 18: val_loss improved from 0.79814 to 0.79411, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 18: val_loss improved from 0.79814 to 0.79411, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 18: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 19: val_loss improved from 0.79411 to 0.79020, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 19: val_loss improved from 0.79411 to 0.79020, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 19: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 20: val_loss improved from 0.79020 to 0.78649, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 20: val_loss improved from 0.79020 to 0.78649, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 20: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to pruned_model/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 21: val_loss improved from 0.78649 to 0.78303, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 21: val_loss improved from 0.78649 to 0.78303, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 21: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 22: val_loss improved from 0.78303 to 0.77997, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 22: val_loss improved from 0.78303 to 0.77997, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 22: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 23: val_loss improved from 0.77997 to 0.77720, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 23: val_loss improved from 0.77997 to 0.77720, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 23: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 24: val_loss improved from 0.77720 to 0.77480, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 24: val_loss improved from 0.77720 to 0.77480, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 24: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 24: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 25: val_loss improved from 0.77480 to 0.77263, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 25: val_loss improved from 0.77480 to 0.77263, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 25: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 25: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 26: val_loss improved from 0.77263 to 0.77032, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 26: val_loss improved from 0.77263 to 0.77032, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 26: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 27: val_loss improved from 0.77032 to 0.76820, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 27: val_loss improved from 0.77032 to 0.76820, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 27: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 27: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 28: val_loss improved from 0.76820 to 0.76622, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 28: val_loss improved from 0.76820 to 0.76622, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 28: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 28: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 29: val_loss improved from 0.76622 to 0.76416, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 29: val_loss improved from 0.76622 to 0.76416, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 29: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 29: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
#
# ***callbacks***
# saving losses to pruned_model/losses.log
#
# Epoch 30: val_loss improved from 0.76416 to 0.76228, saving model to pruned_model/KERAS_check_best_model.h5
#
# Epoch 30: val_loss improved from 0.76416 to 0.76228, saving model to pruned_model/KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to pruned_model/KERAS_check_model_last.h5
#
# Epoch 30: saving model to pruned_model/KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to pruned_model/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Check sparsity
#
# Make a quick check that the model was indeed trained sparse. We’ll just make a histogram of the weights of the 1st layer, and hopefully observe a large peak in the bin containing ‘0’. Note logarithmic y axis.

# %%
bins = np.arange(-2, 2, 0.04)
w_unpruned = model.layers[0].weights[0].numpy().flatten()
w_pruned = pruned_model.layers[0].weights[0].numpy().flatten()

plt.figure(figsize=(7, 7))

plt.hist(w_unpruned, bins=bins, alpha=0.7, label="Unpruned layer 1")
plt.hist(w_pruned, bins=bins, alpha=0.7, label="Pruned layer 1")

plt.xlabel("Weight value")
plt.ylabel("Number of weights")
plt.semilogy()
plt.legend()

print(f"Sparsity of unpruned model layer 1: {np.sum(w_unpruned==0)*100/np.size(w_unpruned)}% zeros")
print(f"Sparsity of pruned model layer 1: {np.sum(w_pruned==0)*100/np.size(w_pruned)}% zeros")
plt.show()
# Out:
# Sparsity of unpruned model layer 1: 0.0% zeros
# Sparsity of pruned model layer 1: 75.0% zeros

# %% [markdown]
# ## Check performance
# How does this 75% sparse model compare against the unpruned model? Let’s report the accuracy and make a ROC curve. The pruned model is shown with solid lines, the unpruned model is shown with dashed lines.

# %%
import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model

unpruned_model = load_model("baseline_model/KERAS_check_best_model.h5")

y_ref = unpruned_model.predict(X_test, verbose=0)
y_prune = pruned_model.predict(X_test, verbose=0)

print("Accuracy unpruned: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_ref, axis=1))))
print("Accuracy pruned:   {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_prune, axis=1))))
# Out:
# Accuracy unpruned: 0.7503072289156627
# Accuracy pruned:   0.742933734939759

# %%
fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.make_roc(y_test, y_ref, classes)
plt.gca().set_prop_cycle(None)  # reset the colors
_ = plotting.make_roc(y_test, y_prune, classes, linestyle="--")

from matplotlib.lines import Line2D

lines = [Line2D([0], [0], ls="-"), Line2D([0], [0], ls="--")]
from matplotlib.legend import Legend

leg = Legend(ax, lines, labels=["Unpruned", "Pruned"], loc="lower right", frameon=False)
ax.add_artist(leg)
plt.show()
