# %%
import numpy as np
import h5py as h5
from matplotlib import pyplot as plt
from IPython.display import Image
import tensorflow as tf

# %%
# %pip install unbinned-unfold==0.1.7
from omnifold import DataLoader, MultiFold, MLP, SetStyle, HistRoutine
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: unbinned-unfold==0.1.7 in /global/u2/v/vmikuni/.local/perlmutter/tensorflow2.9.0/lib/python3.9/site-packages (0.1.7)
# Requirement already satisfied: horovod==0.28.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from unbinned-unfold==0.1.7) (0.28.1)
# Requirement already satisfied: matplotlib in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from unbinned-unfold==0.1.7) (3.8.4)
# Requirement already satisfied: numpy in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from unbinned-unfold==0.1.7) (1.26.4)
# Requirement already satisfied: PyYAML in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from unbinned-unfold==0.1.7) (6.0.1)
# Requirement already satisfied: setuptools in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from unbinned-unfold==0.1.7) (69.5.1)
# Requirement already satisfied: tensorflow in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from unbinned-unfold==0.1.7) (2.9.0)
# Requirement already satisfied: cloudpickle in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from horovod==0.28.1->unbinned-unfold==0.1.7) (3.0.0)
# Requirement already satisfied: psutil in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from horovod==0.28.1->unbinned-unfold==0.1.7) (5.9.8)
# Requirement already satisfied: packaging in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from horovod==0.28.1->unbinned-unfold==0.1.7) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from matplotlib->unbinned-unfold==0.1.7) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from matplotlib->unbinned-unfold==0.1.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from matplotlib->unbinned-unfold==0.1.7) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from matplotlib->unbinned-unfold==0.1.7) (1.4.5)
# Requirement already satisfied: pillow>=8 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from matplotlib->unbinned-unfold==0.1.7) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from matplotlib->unbinned-unfold==0.1.7) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from matplotlib->unbinned-unfold==0.1.7) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from matplotlib->unbinned-unfold==0.1.7) (6.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (1.63.0)
# Requirement already satisfied: h5py>=2.9.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (3.11.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (3.20.3)
# Requirement already satisfied: six>=1.12.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (1.16.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (0.37.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorflow->unbinned-unfold==0.1.7) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow->unbinned-unfold==0.1.7) (0.43.0)
# Requirement already satisfied: zipp>=3.1.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->unbinned-unfold==0.1.7) (3.17.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (7.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /global/common/software/nersc9/tensorflow/2.9.0/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow->unbinned-unfold==0.1.7) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
Image(filename='Omnifold.png')

# %% [markdown]
# # OmniFold Example 1: Gaussians

# %%
def detector(x,std = 0.5):
    """ Create a fake detector response that smears the inputs given a gaussian distribution with mean 0 and std"""
    return x + np.random.normal(size=x.shape)*std

# %%
nevts = 1_000_00 #Number of training events we are going to use
ndim = 4 #Number of features we are going to create

# %%
gen_data = np.random.normal(size=(nevts,ndim),loc=ndim*[0.0],scale=ndim*[1.0])
reco_data = detector(gen_data)
gen_mc = np.random.normal(size=(nevts,ndim),loc=ndim*[1.0],scale=ndim*[1.0])
reco_mc = detector(gen_mc)

data = DataLoader(reco = reco_data,normalize=True)
mc = DataLoader(reco = reco_mc,gen = gen_mc,normalize=True)
# Out:
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...

# %% [markdown]
# ## Let's take a quick look at the data

# %%
SetStyle()
data_dict = {
    'gen_data': gen_data[:,0],
    'reco_data': reco_data[:,0],
    'gen_mc': gen_mc[:,0],
    'reco_mc': reco_mc[:,0],
}
HistRoutine(data_dict,'First Feature [a.u]', reference_name = 'gen_data',plot_ratio=False, binning = np.linspace(-3,5,20))
# Out:
# (<Figure size 900x900 with 1 Axes>,
#  <Axes: xlabel='First Feature [a.u]', ylabel='Normalized number of events'>)

# %% [markdown]
# ## Let's now create the neural network models we are going to use to model the weight distributions

# %%
model1 = MLP(ndim, layer_sizes = [16,32,16], activation = 'gelu')
model2 = MLP(ndim)

# %%
print(model1.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 4)]               0
#
#  dense (Dense)               (None, 16)                80
#
#  dense_1 (Dense)             (None, 32)                544
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Let's now unfold!

# %%
omnifold = MultiFold(
    "Gaussian_test",
    weights_folder = 'weights'
    model1,
    model2,
    data,
    mc,
    batch_size = 1024,
    niter = 1,  #Number of Iterations                                                                                                                                                                                                  
    epochs=10,                                                                                                                                                                                                     
)

# %%
omnifold.Preprocessing()
omnifold.Unfold()
# Out:
# 195 training steps at reco and 195 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/10
#   1/156 [..............................] - ETA: 7:31 - loss: 7.1114WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0023s vs `on_train_batch_end` time: 0.0233s). Check your callbacks.
# 156/156 [==============================] - 4s 5ms/step - loss: 6.6539 - val_loss: 6.2540 - lr: 1.0000e-04
# Epoch 2/10
# 156/156 [==============================] - 1s 5ms/step - loss: 5.9012 - val_loss: 5.5670 - lr: 1.0000e-04
# Epoch 3/10
# 156/156 [==============================] - 1s 5ms/step - loss: 5.2899 - val_loss: 5.0353 - lr: 1.0000e-04
# Epoch 4/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.8431 - val_loss: 4.6644 - lr: 1.0000e-04
# Epoch 5/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.5481 - val_loss: 4.4309 - lr: 1.0000e-04
# Epoch 6/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.3663 - val_loss: 4.2893 - lr: 1.0000e-04
# Epoch 7/10
# 156/156 [==============================] - 1s 4ms/step - loss: 4.2542 - val_loss: 4.2005 - lr: 1.0000e-04
# Epoch 8/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.1817 - val_loss: 4.1428 - lr: 1.0000e-04
# Epoch 9/10
# 156/156 [==============================] - 1s 4ms/step - loss: 4.1343 - val_loss: 4.1051 - lr: 1.0000e-04
# Epoch 10/10
# 156/156 [==============================] - 1s 8ms/step - loss: 4.1032 - val_loss: 4.0820 - lr: 1.0000e-04
# Last val loss 6.253979206085205
# INFO: Dumping training history ...
# RUNNING STEP 2
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/10
#   1/156 [..............................] - ETA: 2:07 - loss: 6.7250WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0021s vs `on_train_batch_end` time: 0.0137s). Check your callbacks.
# 156/156 [==============================] - 2s 5ms/step - loss: 5.6315 - val_loss: 5.1218 - lr: 1.0000e-04
# Epoch 2/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.8237 - val_loss: 4.6293 - lr: 1.0000e-04
# Epoch 3/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.5309 - val_loss: 4.5103 - lr: 1.0000e-04
# Epoch 4/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.4660 - val_loss: 4.4725 - lr: 1.0000e-04
# Epoch 5/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.4421 - val_loss: 4.4533 - lr: 1.0000e-04
# Epoch 6/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.4307 - val_loss: 4.4433 - lr: 1.0000e-04
# Epoch 7/10
# 156/156 [==============================] - 1s 4ms/step - loss: 4.4253 - val_loss: 4.4394 - lr: 1.0000e-04
# Epoch 8/10
# 156/156 [==============================] - 1s 4ms/step - loss: 4.4233 - val_loss: 4.4370 - lr: 1.0000e-04
# Epoch 9/10
# 156/156 [==============================] - 1s 5ms/step - loss: 4.4217 - val_loss: 4.4342 - lr: 1.0000e-04
# Epoch 10/10
# 156/156 [==============================] - 1s 4ms/step - loss: 4.4210 - val_loss: 4.4333 - lr: 1.0000e-04
# Last val loss 5.121763706207275
# INFO: Dumping training history ...

# %% [markdown]
# ## Now, let's evaluate the model!

# %%
validation_data = np.random.normal(size=(nevts,ndim),loc=ndim*[1.0],scale=ndim*[1.0])
unfolded_weights  = omnifold.reweight(validation_data,omnifold.model2,batch_size=1000)

# %%
print(unfolded_weights)
# Out:
# [0.61645854 1.2918739  0.17144737 ... 0.76588845 1.6912955  1.6000457 ]

# %% [markdown]
# ## More plots!

# %%
data_dict = {
    'gen_data': gen_data[:,0],
    'reco_data': reco_data[:,0],
    'gen_mc': gen_mc[:,0],
    'reco_mc': reco_mc[:,0],
    'unfolded': validation_data[:,0],
}

weight_dict = {
    'gen_data': data.weight,
    'reco_data': data.weight,
    'gen_mc': mc.weight,
    'reco_mc': mc.weight,
    'unfolded': unfolded_weights,
    }

fig,_ = HistRoutine(data_dict,'First Feature [a.u]',
                    reference_name = 'gen_data',
                    weights = weight_dict,
                    plot_ratio = False,
                    binning = np.linspace(-3,5,20)
                    )

# %% [markdown]
# # Exercises

# %% [markdown]
# ## The unfolded distribution looks good, but not quite there yet. Try changing:
# * The number of OmniFold iterations
# * The number of training epochs
